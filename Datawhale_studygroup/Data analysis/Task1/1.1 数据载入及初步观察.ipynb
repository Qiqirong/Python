# %%
import numpy as np

# %%
import pandas as pd

# %%
df1=pd.read_csv('D:/data/train.csv')

# %%
df2=pd.read_table('D:\data\\train.csv', sep=',')
# define sep for pd.read_table of excel
# tsv是制表符作为分隔符； csv是‘，’作为分隔符

# %%
chunker=pd.read_csv('D:/data/train.csv', chunksize=1000)
# nrows=1000是只读取1000行

# %%
df3=pd.read_csv('D:/data//train.csv',names=['乘客ID','是否幸存','乘客等级(1/2/3等舱位)','乘客姓名','性别','年龄','堂兄弟/妹个数','父母与小孩个数','船票信息','票价','客舱','登船港口'])
df4=df3.drop(0) #delete row 0 (english)
df4.head()
# Out:
#   乘客ID 是否幸存 乘客等级(1/2/3等舱位)                                               乘客姓名  \
# 1    1    0              3                            Braund, Mr. Owen Harris
# 2    2    1              1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 3    3    1              3                             Heikkinen, Miss. Laina
# 4    4    1              1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 5    5    0              3                           Allen, Mr. William Henry
#
#        性别  年龄 堂兄弟/妹个数 父母与小孩个数              船票信息       票价    客舱 登船港口
# 1    male  22       1       0         A/5 21171     7.25   NaN    S
# 2  female  38       1       0          PC 17599  71.2833   C85    C
# 3  female  26       0       0  STON/O2. 3101282    7.925   NaN    S
# 4  female  35       1       0            113803     53.1  C123    S
# 5    male  35       0       0            373450     8.05   NaN    S

# %%
print (type(df4))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
print (df4.shape)
# Out:
# (891, 12)

# %%
df4.ndim   #维度
# Out:
# 2

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 1 to 891
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   乘客ID            891 non-null    object
#  1   是否幸存            891 non-null    object
#  2   乘客等级(1/2/3等舱位)  891 non-null    object
#  3   乘客姓名            891 non-null    object
#  4   性别              891 non-null    object
#  5   年龄              714 non-null    object
#  6   堂兄弟/妹个数         891 non-null    object
#  7   父母与小孩个数         891 non-null    object
#  8   船票信息            891 non-null    object
#  9   票价              891 non-null    object
#  10  客舱              204 non-null    object
#  11  登船港口            889 non-null    object
# dtypes: object(12)
# memory usage: 90.5+ KB

# %%
df4.tail(15)
# Out:
#     乘客ID 是否幸存 乘客等级(1/2/3等舱位)                                           乘客姓名  \
# 877  877    0              3                  Gustafsson, Mr. Alfred Ossian
# 878  878    0              3                           Petroff, Mr. Nedelio
# 879  879    0              3                             Laleff, Mr. Kristo
# 880  880    1              1  Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)
# 881  881    1              2   Shelley, Mrs. William (Imanita Parrish Hall)
# 882  882    0              3                             Markun, Mr. Johann
# 883  883    0              3                   Dahlberg, Miss. Gerda Ulrika
# 884  884    0              2                  Banfield, Mr. Frederick James
# 885  885    0              3                         Sutehall, Mr. Henry Jr
# 886  886    0              3           Rice, Mrs. William (Margaret Norton)
# 887  887    0              2                          Montvila, Rev. Juozas
# ...

# %%
df4.head(10) #若没有明确几行，默认5行
# Out:
#    乘客ID 是否幸存 乘客等级(1/2/3等舱位)  \
# 1     1    0              3
# 2     2    1              1
# 3     3    1              3
# 4     4    1              1
# 5     5    0              3
# 6     6    0              3
# 7     7    0              1
# 8     8    0              3
# 9     9    1              3
# 10   10    1              2
#
#                                                  乘客姓名      性别   年龄 堂兄弟/妹个数  \
# 1                             Braund, Mr. Owen Harris    male   22       1
# 2   Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38       1
# 3                              Heikkinen, Miss. Laina  female   26       0
# 4        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35       1
# 5                            Allen, Mr. William Henry    male   35       0
# 6                                    Moran, Mr. James    male  NaN       0
# 7                             McCarthy, Mr. Timothy J    male   54       0
# ...

# %%
df4.isnull()   #处理缺失数据常用
# Out:
#       乘客ID   是否幸存  乘客等级(1/2/3等舱位)   乘客姓名     性别     年龄  堂兄弟/妹个数  父母与小孩个数  \
# 1    False  False           False  False  False  False    False    False
# 2    False  False           False  False  False  False    False    False
# 3    False  False           False  False  False  False    False    False
# 4    False  False           False  False  False  False    False    False
# 5    False  False           False  False  False  False    False    False
# ..     ...    ...             ...    ...    ...    ...      ...      ...
# 887  False  False           False  False  False  False    False    False
# 888  False  False           False  False  False  False    False    False
# 889  False  False           False  False  False   True    False    False
# 890  False  False           False  False  False  False    False    False
# 891  False  False           False  False  False  False    False    False
#
#       船票信息     票价     客舱   登船港口
# 1    False  False   True  False
# ...

# %%
df4.to_csv('D:/data/train_chinese.csv', encoding='utf_8_sig', index=False)
# encoding避免中文乱码，index=False是去除最左边的序列编号
